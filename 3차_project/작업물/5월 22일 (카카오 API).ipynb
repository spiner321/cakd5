# %% [markdown]
# # 모듈
# ---

# %%
# !pip install pymysql
import pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.9 MB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
import pymysql
import numpy as np
import pandas as pd

# %% [markdown]
# # # 카카오 로컬
# ---

# %%
import json
import requests

rest_api_key = 'e535b07f417c6dc974507ee3d8c0f9fc'

class KakaoLocalAPI:
    """
    Kakao Local API 컨트롤러
    """

    def __init__(self, rest_api_key):
        """
        Rest API키 초기화 및 기능 별 URL 설정
        """

        # REST API 키 설정
        self.rest_api_key = rest_api_key
        self.headers = {"Authorization": "KakaoAK {}".format(rest_api_key)}

        # 서비스 별 URL 설정

        # 01 주소 검색
        self.URL_01 = "https://dapi.kakao.com/v2/local/search/address.json"
        # 02 좌표-행정구역정보 변환
        self.URL_02 = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json"
        # 03 좌표-주소 변환
        self.URL_03 = "https://dapi.kakao.com/v2/local/geo/coord2address.json"
        # 04 좌표계 변환
        self.URL_04 = "https://dapi.kakao.com/v2/local/geo/transcoord.json"
        # 05 키워드 검색
        self.URL_05 = "https://dapi.kakao.com/v2/local/search/keyword.json"
        # 06 카테고리 검색
        self.URL_06 = "https://dapi.kakao.com/v2/local/search/category.json"

    def search_address(self, query, analyze_type=None, page=None, size=None):
        """
        01 주소 검색
        """
        params = {"query": f"{query}"}

        if analyze_type != None:
            params["analyze_type"] = f"{analyze_type}"

        if page != None:
            params['page'] = f"{page}"

        if size != None:
            params['size'] = f"{size}"

        res = requests.get(self.URL_01, headers=self.headers, params=params)
        document = json.loads(res.text)

        return document
    
    def geo_coord2regioncode(self, x, y, input_coord=None, output_coord=None):
        """
        02 좌표-행정구역정보 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
        
        if output_coord != None:
            params['output_coord'] = f"{output_coord}"
            
        res = requests.get(self.URL_02, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def geo_coord2address(self, x, y, input_coord=None):
        """
        03 좌표-주소 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
            
        res = requests.get(self.URL_03, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def geo_transcoord(self, x, y, output_coord, input_coord=None):
        """
        04 좌표계 변환
        """
        params = {"x": f"{x}",
                  "y": f"{y}",
                  "output_coord": f"{output_coord}"}
        
        if input_coord != None:
            params['input_coord'] = f"{input_coord}"
        
        res = requests.get(self.URL_04, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
        
    
    def search_keyword(self,query,category_group_code=None,x=None,y=None,radius=None,rect=None,page=None,size=None,sort=None):
        """
        05 키워드 검색
        """
        params = {"query": f"{query}"}
        
        if category_group_code != None:
            params['category_group_code'] = f"{category_group_code}"
        if x != None:
            params['x'] = f"{x}"
        if y != None:
            params['y'] = f"{y}"
        if radius != None:
            params['radius'] = f"{radius}"
        if rect != None:
            params['rect'] = f"{rect}"
        if page != None:
            params['page'] = f"{page}"
        if size != None:
            params['size'] = f"{params}"
        if sort != None:
            params['sort'] = f"{sort}"
        
        res = requests.get(self.URL_05, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document
    
            
        
    def search_category(self, category_group_code, x, y, radius=None, rect=None, page=None, size=None, sort=None):
        """
        06 카테고리 검색
        """
        params = {'category_group_code': f"{category_group_code}",
                  'x': f"{x}",
                  'y': f"{y}"}
        
        if radius != None:
            params['radius'] = f"{radius}"
        if rect != None:
            params['rect'] = f"{rect}"
        if page != None:
            params['page'] = f"{page}"
        if size != None:
            params['size'] = f"{size}"
        if sort != None:
            params['sort'] = f"{sort}"
            
        res = requests.get(self.URL_06, headers=self.headers, params=params)
        document = json.loads(res.text)
        
        return document

# %%
klocal = KakaoLocalAPI(rest_api_key)
klocal.search_keyword('관악산')
# Out:
# {'documents': [{'address_name': '서울 관악구 신림동 산 56-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 산',
#    'distance': '',
#    'id': '8184985',
#    'phone': '',
#    'place_name': '관악산',
#    'place_url': 'http://place.map.kakao.com/8184985',
#    'road_address_name': '',
#    'x': '126.96389684735281',
#    'y': '37.44446951034434'},
#   {'address_name': '경기 과천시 중앙동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 산',
#    'distance': '',
#    'id': '17614924',
#    'phone': '',
#    'place_name': '관악산 연주대',
#    'place_url': 'http://place.map.kakao.com/17614924',
#    'road_address_name': '',
#    'x': '126.964176894234',
#    'y': '37.44490568659'},
#   {'address_name': '서울 관악구 신림동 산 56-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 계곡',
#    'distance': '',
#    'id': '24424140',
#    'phone': '',
#    'place_name': '관악산계곡',
#    'place_url': 'http://place.map.kakao.com/24424140',
#    'road_address_name': '',
#    'x': '126.95662095589033',
#    'y': '37.45719297964732'},
#   {'address_name': '경기 과천시 중앙동',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '스포츠,레저 > 등산 > 등산정보',
#    'distance': '',
#    'id': '17553885',
#    'phone': '',
#    'place_name': '관악산 연주암분기점',
#    'place_url': 'http://place.map.kakao.com/17553885',
#    'road_address_name': '',
#    'x': '126.965055262082',
#    'y': '37.4418172710219'},
#   {'address_name': '서울 관악구 신림동 205-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 공원 > 도시근린공원',
#    'distance': '',
#    'id': '62638585',
#    'phone': '',
#    'place_name': '관악산공원',
#    'place_url': 'http://place.map.kakao.com/62638585',
#    'road_address_name': '',
#    'x': '126.948127197772',
#    'y': '37.4619865456868'},
#   {'address_name': '서울 관악구 신림동 1735',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '부동산 > 주거시설 > 아파트',
#    'distance': '',
#    'id': '11033659',
#    'phone': '',
#    'place_name': '관악산휴먼시아2단지아파트',
#    'place_url': 'http://place.map.kakao.com/11033659',
#    'road_address_name': '서울 관악구 난곡로 55',
#    'x': '126.91968237692367',
#    'y': '37.45903694158076'},
#   {'address_name': '서울 관악구 신림동',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '교통,수송 > 입출구',
#    'distance': '',
#    'id': '8664101',
#    'phone': '',
#    'place_name': '관악산 입구',
#    'place_url': 'http://place.map.kakao.com/8664101',
#    'road_address_name': '',
#    'x': '126.946264515559',
#    'y': '37.4681774634472'},
#   {'address_name': '서울 관악구 신림동 210',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 문화유적 > 탑,비석',
#    'distance': '',
#    'id': '27510417',
#    'phone': '',
#    'place_name': '관악산입구시계탑',
#    'place_url': 'http://place.map.kakao.com/27510417',
#    'road_address_name': '서울 관악구 신림로 23',
#    'x': '126.945527447615',
#    'y': '37.4682275825838'},
#   {'address_name': '서울 관악구 신림동 산 56-1',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '사회,공공기관 > 행정기관 > 기상청 > 기상관측소',
#    'distance': '',
#    'id': '8663444',
#    'phone': '',
#    'place_name': '관악산기상관측소',
#    'place_url': 'http://place.map.kakao.com/8663444',
#    'road_address_name': '서울 관악구 관악로 1',
#    'x': '126.96398493240729',
#    'y': '37.44459387722682'},
#   {'address_name': '서울 관악구 신림동',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 공원',
#    'distance': '',
#    'id': '26203515',
#    'phone': '',
#    'place_name': '관악산호수공원',
#    'place_url': 'http://place.map.kakao.com/26203515',
#    'road_address_name': '',
#    'x': '126.947220872691',
#    'y': '37.4584938214641'},
#   {'address_name': '경기 안양시 동안구 비산동',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 산봉우리',
#    'distance': '',
#    'id': '15166508',
#    'phone': '',
#    'place_name': '관악산 국기봉',
#    'place_url': 'http://place.map.kakao.com/15166508',
#    'road_address_name': '',
#    'x': '126.962452619719',
#    'y': '37.4309213898246'},
#   {'address_name': '경기 과천시 관문동 산 11-6',
#    'category_group_code': 'PK6',
#    'category_group_name': '주차장',
#    'category_name': '교통,수송 > 교통시설 > 주차장',
#    'distance': '',
#    'id': '20513472',
#    'phone': '',
#    'place_name': '관악산주차장',
#    'place_url': 'http://place.map.kakao.com/20513472',
#    'road_address_name': '',
#    'x': '126.990920008284',
#    'y': '37.434790562568'},
#   {'address_name': '경기 과천시 중앙동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 계곡',
#    'distance': '',
#    'id': '15168291',
#    'phone': '',
#    'place_name': '관악산 문원하폭포',
#    'place_url': 'http://place.map.kakao.com/15168291',
#    'road_address_name': '',
#    'x': '126.971016774107',
#    'y': '37.4313238512605'},
#   {'address_name': '서울 관악구 신림동 210',
#    'category_group_code': 'PK6',
#    'category_group_name': '주차장',
#    'category_name': '교통,수송 > 교통시설 > 주차장',
#    'distance': '',
#    'id': '26537056',
#    'phone': '',
#    'place_name': '관악산공원 주차장',
#    'place_url': 'http://place.map.kakao.com/26537056',
#    'road_address_name': '서울 관악구 관악산나들길 4',
#    'x': '126.945215236883',
#    'y': '37.4685229698089'},
#   {'address_name': '서울 관악구 남현동 1129-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 도보여행 > 둘레길 > 관악산둘레길',
#    'distance': '',
#    'id': '18741240',
#    'phone': '',
#    'place_name': '관악산둘레길 애국의숲길1구간',
#    'place_url': 'http://place.map.kakao.com/18741240',
#    'road_address_name': '',
#    'x': '126.95932590178974',
#    'y': '37.47132901045152'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '관악산', 'region': [], 'selected_region': ''},
#   'total_count': 237}}

# %% [markdown]
# # # 카카오 내비
# ---
# - 참고 : https://developers.kakao.com/docs/latest/ko/kakaonavi/rest-api

# %%
# rest_api_key = 'e535b07f417c6dc974507ee3d8c0f9fc'
rest_api_key = '41239f1ad95324b1d51bf118d1e84251'

def knavi(rest_api_key, origin, destination, priority = 'RECOMMEND'):
    import json
    import requests
    
    headers = {"Authorization": f"KakaoAK {rest_api_key}"}
    url = f"https://apis-navi.kakaomobility.com/v1/directions?origin={origin}&destination={destination}&waypoints=&priority={priority}&car_fuel=GASOLINE&car_hipass=false&alternatives=false&road_details=false"
    
    res = requests.get(url, headers=headers)
    document = json.loads(res.text)

    return document

# %%
origin = '127.061883, 37.647144'
destination = '127.031403, 37.575399'

temp = knavi(rest_api_key, origin, destination)
duration = temp['routes'][0]['summary']['duration'] # 초
duration
# Out:
# 2003

# %%
temp
# Out:
# {'routes': [{'result_code': 0,
#    'result_msg': '길찾기 성공',
#    'sections': [{'bound': {'max_x': 127.07743986311897,
#       'max_y': 37.647104560260765,
#       'min_x': 127.03057898783301,
#       'min_y': 37.560714708149426},
#      'distance': 15373,
#      'duration': 2003,
#      'guides': [{'distance': 0,
#        'duration': 0,
#        'guidance': '출발지',
#        'name': '출발지',
#        'road_index': 0,
#        'type': 100,
#        'x': 127.06159429021241,
#        'y': 37.647077802308075},
#       {'distance': 155,
#        'duration': 35,
#        'guidance': '좌회전',
#        'name': '',
#        'road_index': 1,
#        'type': 1,
#        'x': 127.05993287343283,
#        'y': 37.6467311917815},
#       {'distance': 188,
#        'duration': 31,
#        'guidance': '우회전',
#        'name': '',
#        'road_index': 2,
#        'type': 2,
#        'x': 127.05998764399952,
#        'y': 37.64508273367298},
#       {'distance': 468,
#        'duration': 197,
#        'guidance': '좌회전',
#        'name': '녹천교',
#        'road_index': 3,
#        'type': 1,
#        'x': 127.05478849305767,
#        'y': 37.6458160821809},
#       {'distance': 608,
#        'duration': 80,
#        'guidance': '성수대교 방면으로 왼쪽에 도시고속도로 입구',
#        'name': '',
#        'road_index': 4,
#        'type': 46,
#        'x': 127.05426704188851,
#        'y': 37.64046876372862},
#       {'distance': 873,
#        'duration': 97,
#        'guidance': '12시 방향',
#        'name': '월계1교',
#        'road_index': 5,
#        'type': 29,
#        'x': 127.06032697869156,
#        'y': 37.63433607492148},
#       {'distance': 1580,
#        'duration': 170,
#        'guidance': '중랑교 강변북로 방면으로 12시 방향',
#        'name': '월릉교',
#        'road_index': 6,
#        'type': 29,
#        'x': 127.06971853001633,
#        'y': 37.62259788402911},
#       {'distance': 2451,
#        'duration': 126,
#        'guidance': '군자교 강변북로 방면으로 12시 방향',
#        'name': '중랑교',
#        'road_index': 7,
#        'type': 29,
#        'x': 127.0711919694836,
#        'y': 37.60067814996498},
#       {'distance': 2152,
#        'duration': 142,
#        'guidance': '강변북로 방면으로 12시 방향',
#        'name': '장안교',
#        'road_index': 8,
#        'type': 29,
#        'x': 127.07451449335693,
#        'y': 37.582953677768806},
#       {'distance': 1848,
#        'duration': 126,
#        'guidance': '장한평역 천호대교 방면으로 오른쪽 고속도로 진입',
#        'name': '군자교',
#        'road_index': 9,
#        'type': 49,
#        'x': 127.07510631347498,
#        'y': 37.56714494367752},
#       {'distance': 626,
#        'duration': 204,
#        'guidance': '장한평역 방면으로 오른쪽에 도시고속도로 출구',
#        'name': '군자교',
#        'road_index': 10,
#        'type': 44,
#        'x': 127.07197693126469,
#        'y': 37.56208352603858},
#       {'distance': 2171,
#        'duration': 388,
#        'guidance': '신설동역 시청 방면으로 지하차도 진입',
#        'name': '신답지하차도',
#        'road_index': 11,
#        'type': 15,
#        'x': 127.05135781295814,
#        'y': 37.56801072633422},
#       {'distance': 898,
#        'duration': 98,
#        'guidance': '동대문구청 신설동역 방면으로 오른쪽 직진',
#        'name': '신답철교',
#        'road_index': 12,
#        'type': 83,
#        'x': 127.04303614206052,
#        'y': 37.57255691646522},
#       {'distance': 1098,
#        'duration': 230,
#        'guidance': '용두동사거리 방면으로 우회전',
#        'name': '시립동부병원앞',
#        'road_index': 13,
#        'type': 2,
#        'x': 127.03101766633715,
#        'y': 37.57399966363033},
#       {'distance': 185,
#        'duration': 45,
#        'guidance': '우회전',
#        'name': '',
#        'road_index': 14,
#        'type': 2,
#        'x': 127.03057898783301,
#        'y': 37.57552783666888},
#       {'distance': 72,
#        'duration': 34,
#        'guidance': '목적지',
#        'name': '목적지',
#        'road_index': -1,
#        'type': 101,
#        'x': 127.0313937793414,
#        'y': 37.575552545935224}],
#      'roads': [{'distance': 155,
#        'duration': 35,
#        'name': '',
#        'traffic_speed': 16.0,
#        'traffic_state': 0,
#        'vertexes': [127.06159429021241,
#         37.647077802308075,
#         127.06159429021241,
#         37.647077802308075,
#         127.06155995791968,
#         37.647104560260765,
#         127.06151463494358,
#         37.64710419971463,
#         127.06082527479595,
#         37.64695454805442,
#         127.06064443716915,
#         37.64691706684899,
#         127.0606107854456,
#         37.64688976783426,
#         127.06055435886039,
#         37.646871297799365,
#         127.06014758876874,
#         37.64677795432794,
#         127.06014758876874,
#         37.64677795432794,
#         127.05993287343283,
#         37.6467311917815]},
#       {'distance': 188,
#        'duration': 31,
#        'name': '덕릉로',
#        'traffic_speed': 22.0,
#        'traffic_state': 0,
#        'vertexes': [127.05993287343283,
#         37.6467311917815,
#         127.0600500405491,
#         37.646425773424674,
#         127.0600500405491,
#         37.646425773424674,
#         127.06014409140316,
#         37.64615621218049,
#         127.06016811485404,
#         37.64604827933755,
#         127.06016811485404,
#         37.64604827933755,
#         127.06019179767796,
#         37.6459673748321,
#         127.06005233417191,
#         37.64534454936794,
#         127.06005233417191,
#         37.64534454936794,
#         127.05998764399952,
#         37.64508273367298]},
#       {'distance': 468,
#        'duration': 197,
#        'name': '덕릉로',
#        'traffic_speed': 10.0,
#        'traffic_state': 2,
#        'vertexes': [127.05998764399952,
#         37.64508273367298,
#         127.05825078978235,
#         37.645330181798506,
#         127.05825078978235,
#         37.645330181798506,
#         127.05750161319283,
#         37.64543232313198,
#         127.05750161319283,
#         37.64543232313198,
#         127.05704759688678,
#         37.64549176752022,
#         127.05704759688678,
#         37.64549176752022,
#         127.05671832924428,
#         37.645543197334575,
#         127.05671832924428,
#         37.645543197334575,
#         127.05652536902359,
#         37.645568685361184,
#         127.05652536902359,
#         37.645568685361184,
#         127.05508365743165,
#         37.64577339496947,
#         127.05508365743165,
#         37.64577339496947,
#         127.05478849305767,
#         37.6458160821809]},
#       {'distance': 608,
#        'duration': 80,
#        'name': '',
#        'traffic_speed': 37.0,
#        'traffic_state': 3,
#         37.57555143127448,
#         127.0313937793414,
#         37.575552545935224]}]}],
#    'summary': {'bound': {'max_x': 127.07651658391738,
#      'max_y': 37.64722258974049,
#      'min_x': 127.0307751346925,
#      'min_y': 37.56039189205551},
#     'destination': {'name': '',
#      'x': 127.03139576322894,
#      'y': 37.57539938475484},
#     'distance': 15373,
#     'duration': 2003,
#     'fare': {'taxi': 16000, 'toll': 0},
#     'origin': {'name': '', 'x': 127.06187676549744, 'y': 37.64714312140026},
#     'priority': 'RECOMMEND',
#     'waypoints': []}}],
#  'trans_id': '01857310c3294686b29f62013493eec7'}

# %% [markdown]
# # # 혈액배송 소요 시간
# ---

# %%
conn = pymysql.connect(host='34.64.132.212', user='root', password='ASewetsvc124~1242#%1wsdeWXV', db='source')
sql_state='SELECT * FROM `군집화된병원3`'
hospital=pd.read_sql_query(sql_state, conn)
hospital.head()
# Out:
#        기관ID                     기관명          경도         위도 응급실 수술실  입원실   병상수  \
# 0  A1100008  (학)고려대학교의과대학부속병원(안암병원)  127.026471  37.587156  32  22  837  1048
# 1  A1100001                 경희대학교병원  127.051832  37.593877  21  16  604   850
# 2  A1100048               노원을지대학교병원  127.070003  37.636443  23  10  449   512
# 3  A1100044                    녹색병원  127.086055  37.583621  10   3  299   318
# 4  A1100021                  삼육서울병원  127.065329  37.587992  21   5  406   431
#
#    agglo_cluster    중심거리지수
# 0              2  0.262140
# 1              2  0.594199
# 2              2  0.295250
# 3              2  0.301593
# 4              2  0.478078

# %%
bloodbank = ['서울동부혈액원', '서울중앙혈액원', '서울남부혈액원']

# %%
durations = []
distances = []
for i in bloodbank:
    start_lon = float(hospital.loc[hospital['기관명'] == i, '경도'])
    start_lan = float(hospital.loc[hospital['기관명'] == i, '위도'])
    start = f'{start_lon}, {start_lan}'

    bloodbank_cluster = int(hospital.loc[hospital['기관명'] == i, 'agglo_cluster'])
    hospital_name = hospital.loc[hospital['agglo_cluster'] == bloodbank_cluster, '기관명']

    for j in hospital_name:
        goal_lon = float(hospital.loc[hospital['기관명'] == j, '경도'])
        goal_lan = float(hospital.loc[hospital['기관명'] == j, '위도'])
        goal = f'{goal_lon}, {goal_lan}'

        navi = knavi(rest_api_key, start, goal)
        try:
            duration = navi['routes'][0]['summary']['duration']
            distance = navi['routes'][0]['summary']['distance']
        except KeyError:
            duration = 0
            distance = 0

        durations.append(duration)
        distances.append(distance)

# %%
hospital['duration'] = np.round(np.array(durations)/60, 2)
hospital['distance'] = np.round(np.array(distances)/1000, 2)

hospital
# Out:
#         기관ID                     기관명          경도         위도   응급실   수술실   입원실  \
# 0   A1100008  (학)고려대학교의과대학부속병원(안암병원)  127.026471  37.587156    32    22   837
# 1   A1100001                 경희대학교병원  127.051832  37.593877    21    16   604
# 2   A1100048               노원을지대학교병원  127.070003  37.636443    23    10   449
# 3   A1100044                    녹색병원  127.086055  37.583621    10     3   299
# 4   A1100021                  삼육서울병원  127.065329  37.587992    21     5   406
# 5   A1100050                  서울성심병원  127.049838  37.584191     6     6   213
# 6   A1100022               서울특별시동부병원  127.031403  37.575399    10     3   192
# 7   A1100035              서울특별시서울의료원  127.098091  37.612869    22     9   549
#      병상수  agglo_cluster    중심거리지수  duration  distance
# 0   1048              2  0.262140     31.45      9.28
# 1    850              2  0.594199     29.57      9.74
# 2    512              2  0.295250      8.50      2.11
# 3    318              2  0.301593     30.52      8.46
# 4    431              2  0.478078     24.65      8.51
# 5    224              2  0.367704     26.68      9.39
# 6    202              2  0.227130     33.95     10.09
# 7    623              2  0.308278     21.73      6.32
# 8    104              2  0.238930     29.82      9.02
# 9    449              2  0.189759     20.28      4.14
# 10   587              2  0.214337      5.15      1.04
# 11   481              2  0.326688     13.35      4.39
# 12   846              2  0.184883     38.15     13.48
# 13  None              2  0.221978      0.00      0.00
# 14   440              0  0.456896     23.00     10.30
# 15   689              0  0.164302     40.07     11.85
# 16  1075              0  0.192111     30.43      8.08
# 17   202              0  0.175072     27.87      6.93
# 18   208              0  0.218792     33.87     11.57
# 19   243              0  0.225562     33.72      9.34
# 20   231              0  0.152453      6.90      2.13
# 21  1758              0  0.111353     47.43     15.04
# 22   293              0  0.168807     38.42     11.52
# 23   763              0  0.239505     38.33     11.96
# 24   330              0  0.129009     33.58      7.87
# 25   276              0  0.467517     22.55      8.29
# 26   218              0  0.164831     40.52     11.17
# 27   299              0  0.186918     38.12     12.54
# 28  2454              0  0.248658     36.02      9.59
# 29   207              0  0.171781     35.68      8.70
# 30   202              0  0.100067     46.38     13.82
# 31   779              0  0.351162     12.55      2.44
# 32   205              0  0.136432     44.87     16.30
# 33   776              0  0.215845     23.05     11.36
# 34   587              0  0.234442     29.53     11.31
# 35   295              0  0.209409     12.28      3.32
# 36   214              0  0.117585     48.17     13.93
# 37  None              0  0.219602      0.00      0.00
# 38   667              1  0.132851     52.85     15.01
# 39   869              1  0.360123     46.37     10.32
# 40   450              1  0.239797     31.40      8.53
# 41  1979              1  0.304714     19.45      4.85
# 42   614              1  0.205029     45.68     12.46
# 43   725              1  0.136869     42.93      8.23
# 44   815              1  0.227143     19.70      2.91
# 45  2705              1  0.439671     40.18     10.37
# 46  1356              1  0.137163     40.67      6.90
# 47   988              1  0.179343     46.53     12.48
# 48   255              1  0.518345     47.63     10.40
# 49  None              1  0.196042      0.00      0.00

# %%
hospital.drop(hospital.loc[hospital['기관ID'].isnull()].index, axis = 0).describe()
# Out:
#                경도         위도  agglo_cluster     중심거리지수   duration   distance
# count   47.000000  47.000000      47.000000  47.000000  47.000000  47.000000
# mean   126.998542  37.548378       0.787234   0.249118  31.713404   9.101915
# std      0.088669   0.048448       0.858111   0.116083  12.061299   3.721931
# min    126.833130  37.455671       0.000000   0.100067   5.150000   1.040000
# 25%    126.923208  37.504438       0.000000   0.170294  23.025000   7.400000
# 50%    127.004418  37.540845       1.000000   0.218792  33.580000   9.390000
# 75%    127.071063  37.582363       2.000000   0.303154  40.350000  11.545000
# max    127.157522  37.648581       2.000000   0.594199  52.850000  16.300000

# %%
import pymysql
from sqlalchemy import create_engine

db_connection_str = 'mysql+pymysql://root:ASewetsvc124~1242#%1wsdeWXV@34.64.132.212:3306/source'
db_connection = create_engine(db_connection_str)
conn = db_connection.connect()

hospital.to_sql(name = '도로혈액배송소요시간',con = db_connection, index = False, if_exists = 'replace')
