# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ##### [과제] mtcars.csv 를 불러와서 0~1 스케일로 정규화한 후 qsec 컬럼이 0.5보다 큰 관측치의 개수를 구하시오.

# %%
df = pd.read_csv('mtcars.csv',index_col = 0)
index = df.index.tolist()
columns = df.columns.tolist()
scaler = MinMaxScaler()
df = scaler.fit_transform(df)
df = pd.DataFrame(df, index, columns)
df
# Out:
#                           mpg  cyl      disp        hp      drat        wt  \
# Mazda RX4            0.451064  0.5  0.221751  0.204947  0.525346  0.283048
# Mazda RX4 Wag        0.451064  0.5  0.221751  0.204947  0.525346  0.348249
# Datsun 710           0.527660  0.0  0.092043  0.144876  0.502304  0.206341
# Hornet 4 Drive       0.468085  0.5  0.466201  0.204947  0.147465  0.435183
# Hornet Sportabout    0.353191  1.0  0.720629  0.434629  0.179724  0.492713
# Valiant              0.327660  0.5  0.383886  0.187279  0.000000  0.497827
# Duster 360           0.165957  1.0  0.720629  0.681979  0.207373  0.525952
# Merc 240D            0.595745  0.0  0.188576  0.035336  0.428571  0.428791
# Merc 230             0.527660  0.0  0.173859  0.151943  0.534562  0.418563
# Merc 280             0.374468  0.5  0.240708  0.250883  0.534562  0.492713
# Merc 280C            0.314894  0.5  0.240708  0.250883  0.534562  0.492713
# ...

# %%
dfq = df[df['qsec'] > 0.5]
dfq
# Out:
#                      mpg  cyl      disp        hp      drat        wt  \
# Hornet 4 Drive  0.468085  0.5  0.466201  0.204947  0.147465  0.435183
# Valiant         0.327660  0.5  0.383886  0.187279  0.000000  0.497827
# Merc 240D       0.595745  0.0  0.188576  0.035336  0.428571  0.428791
# Merc 230        0.527660  0.0  0.173859  0.151943  0.534562  0.418563
# Merc 280C       0.314894  0.5  0.240708  0.250883  0.534562  0.492713
# Fiat 128        0.936170  0.0  0.018957  0.049470  0.608295  0.175658
# Toyota Corolla  1.000000  0.0  0.000000  0.045936  0.672811  0.082332
# Toyota Corona   0.472340  0.0  0.122225  0.159011  0.433180  0.243416
# Fiat X1-9       0.719149  0.0  0.019706  0.049470  0.608295  0.107901
#
#                     qsec   vs   am  gear      carb
# Hornet 4 Drive  0.588095  1.0  0.0   0.0  0.000000
# Valiant         0.680952  1.0  0.0   0.0  0.000000
# Merc 240D       0.654762  1.0  0.0   0.5  0.142857
# Merc 230        1.000000  1.0  0.0   0.5  0.142857
# ...

# %%
print(dfq.qsec.value_counts, '\n')
print(dfq.value_counts('qsec'), '\n')
dfq.value_counts('qsec').sum()
# Out:
# <bound method IndexOpsMixin.value_counts of Hornet 4 Drive    0.588095
# Valiant           0.680952
# Merc 240D         0.654762
# Merc 230          1.000000
# Merc 280C         0.523810
# Fiat 128          0.591667
# Toyota Corolla    0.642857
# Toyota Corona     0.655952
# Fiat X1-9         0.523810
# Name: qsec, dtype: float64>
#
# qsec
# 0.523810    2
# 0.588095    1
# 0.591667    1
# 0.642857    1
# 0.654762    1
# 0.655952    1
# 0.680952    1
# 1.000000    1
# dtype: int64
# 9

# %%
df = pd.read_csv('mtcars.csv',index_col = 0)
scaler = MinMaxScaler()
dfq = np.array(df['qsec']).reshape(-1, 1)
dfq = scaler.fit_transform(dfq)
dfq1 = dfq[dfq > 0.5]
len(dfq1)
# Out:
# 9
