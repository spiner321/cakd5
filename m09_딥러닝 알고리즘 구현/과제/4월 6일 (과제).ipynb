# %% [markdown]
# ##### [과제] 뉴스 기사 분류의 유닛수를 32개, 128개로 조정하고 한 개의 은닉층을 세 개의 은닉층으로 변경하여 학습 및 평가
# ---

# %% [markdown]
# 완성한 데이터는 4월 5일 (뉴스 기사 분류 - 다중 분류).ipynb 파일에 있음

# %% [markdown]
# ##### [과제] 주택 가격 예측을 epochs = 500으로 적용하여 학습 및 평가
# ---

# %% [markdown]
# 완성한 데이터는 4월 6일 (주택 가격 예측 - 회귀).ipynb 파일에 있음

# %% [markdown]
# ##### [과제] 영화 리뷰 분류에 대해서 아래 사항을 수행
# ---
# - 더 작은 네트워크로 변경해 그 효과를 설명 (출력 유닛 수 6)
# - 더 큰 네트워크로 변경해 그 효과를 설명 (출력 유닛 수 1024)
# - l2규제를 추가하여 그 효과를 설명

# %% [markdown]
# 완성한 데이터는 4월 6일 (과대적합, 과소적합).ipynb 파일에 있음
