# %% [markdown]
# ##### [과제] 데이터 증식하여 모델 학습, 평가 및 시각화
# ---

# %% [markdown]
# 완성한 데이터는 4월 8일 ~ 4월 11일 (소규모 데이터셋에서 컨브넷 훈련).ipynb에 있음

# %% [markdown]
# ##### [과제] 데이터 증식을 사용하여 모델링, 학습, 평가 및 시각화를 수행 후 인사이트를 기술하세요.
# ---

# %% [markdown]
# 완성한 데이터는 4월 11일 (사전 훈련된 컨브넷).ipynb에 있음
