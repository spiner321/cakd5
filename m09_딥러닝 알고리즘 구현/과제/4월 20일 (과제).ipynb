# %% [markdown]
# ##### [과제] jena_climate 데이터셋에 대하여 CNN을 이용하여 모델 학습 및 검증을 수행한 후 그 성능을 상식 수준의 기준점과 비교하세요.
# ---

# %% [markdown]
# 완성한 데이터는 4월 20일 (RNN + CNN을 활용한 시퀀스 처리).ipynb에 있음.

# %% [markdown]
# ##### [과제] jena_climate 데이터셋 제너레이터 함수에 step을 6 대신 3으로 변경 적용한 후 상기 과제를 CNN과 RNN을 연결하는 방식으로 수행하고 그 성능에 대하여 평가하세요.
# ---

# %% [markdown]
# 완성한 데이터는 4월 20일 (RNN + CNN을 활용한 시퀀스 처리).ipynb에 있음.

# %% [markdown]
# ##### [과제] 3, 4, 5차원 텐서를 생성하여 출력하세요.
# ---

# %% [markdown]
# 완성한 데이터는 4월 20일 (PyTorch 기초).ipynb에 있음.

# %% [markdown]
# ##### [과제] 2차원 텐서 x,y를 생성하여 덧셈(add), 뺄셈(sub), 곱셈(mul), 나눗셈(div), 내적(matmul, mm) 연산 사례를 pytorch로 1개 이상씩 수행하세요.
# ---

# %% [markdown]
# 완성한 데이터는 4월 20일 (PyTorch 기초).ipynb에 있음.
