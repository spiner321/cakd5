# %% [markdown]
# ##### [과제] 시계열 데이터를 완전연결층에서 분석했을때 생기는 문제를 해결하기 위해 순환 시퀀스 처리 모델을 적용하여 데이터 포인트의 시간 순서를 사용하여 과제를 수행하세요. (LSTM, GRU)
# ---

# %% [markdown]
# 완성한 데이터는 4월 19일 (RNN 고급 사용법).ipynb에 있음

# %% [markdown]
# ##### [과제] 과대적합을 줄이기 위한 방법을 수행하세요.
# ---
# - 순환 드롭아웃
# - 스태킹 순환 층
# - 양방향 RNN 사용

# %% [markdown]
# 완성한 데이터는 4월 19일 (RNN 고급 사용법).ipynb에 있음
