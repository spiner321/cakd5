# %%
p1_sum = ['백화점상품권10만원','외식상품권12만원']
p2_sum = ['백화점상품권5만원','외식상품권7만원']
p1_avg = ['백화점상품권 20만원','외식상품권25만원']
p2_avg = ['백화점상품권 15만원','외식상품권 15만원']

import numpy as np

Brand_A20 = np.random.randint(500,10001,size=12).tolist()
Brand_B20 = np.random.randint(500,10001,size=12).tolist()
Brand_C20 = np.random.randint(500,10001,size=12).tolist()
Brand_D20 = np.random.randint(500,10001,size=12).tolist()
Brand_E20 = np.random.randint(500,10001,size=12).tolist()

Brand_A21 = np.random.randint(500,10001,size=12).tolist()
Brand_B21 = np.random.randint(500,10001,size=12).tolist()
Brand_C21 = np.random.randint(500,10001,size=12).tolist()
Brand_D21 = np.random.randint(500,10001,size=12).tolist()
Brand_E21 = np.random.randint(500,10001,size=12).tolist()


result_A20=sum(Brand_A20)
result_B20=sum(Brand_B20)
result_C20=sum(Brand_C20)
result_D20=sum(Brand_D20)
result_E20=sum(Brand_E20)
result_B20=sum(Brand_B20)

result_A21=sum(Brand_A21)
result_B21=sum(Brand_B21)
result_C21=sum(Brand_C21)
result_D21=sum(Brand_D21)
result_E21=sum(Brand_E21)
result_B21=sum(Brand_B21)

print("※리스트 안의 각 숫자는 1월부터 12월까지의 월별 매출입니다. (단위: 1만원)\n")
print("2020년도\n")
print("A브랜드: "f'{Brand_A20}  20년도 연매출은 {result_A20} 입니다.\n')
print("B브랜드: "f'{Brand_B20}  20년도 연매출은 {result_B20} 입니다.\n')
print("C브랜드: "f'{Brand_C20}  20년도 연매출은 {result_C20} 입니다.\n')
print("D브랜드: "f'{Brand_D20}  20년도 연매출은 {result_D20} 입니다.\n')
print("E브랜드: "f'{Brand_E20}  20년도 연매출은 {result_E20} 입니다.\n')
print("="*110)
print("")
print("2021년도\n")
print("A브랜드: "f'{Brand_A21}  21년도 연매출은 {result_A21} 입니다.\n')
print("B브랜드: "f'{Brand_B21}  21년도 연매출은 {result_B21} 입니다.\n')
print("C브랜드: "f'{Brand_C21}  21년도 연매출은 {result_C21} 입니다.\n')
print("D브랜드: "f'{Brand_D21}  21년도 연매출은 {result_D21} 입니다.\n')
print("E브랜드: "f'{Brand_E21}  21년도 연매출은 {result_E21} 입니다.\n\n')
print("우수한 매출을 달성한 브랜드를 위한 시상이 있겠습니다.\n")



li0 = [result_A20,result_B20,result_C20,result_D20,result_E20]
li1 = [result_A21,result_B21,result_C21,result_D21,result_E21]
li2 = ['A브랜드','B브랜드','C브랜드','D브랜드','E브랜드']
t=li1.index(max(li1))
s=li2[t]
r=li0.index(max(li0))
m=li2[r]



print(f'축하드립니다.{s}가 {max(li1)}0000원으로 연매출 1위 달성 하였습니다.')

while 1:
    
    v1 =int(input("2021년도 매출 1등상품은 (1. 백화점상품권10만원, 2. 외식상품권12만원) 입니다.상품을 고르세요(1,2): "))
    if v1 == 1 or v1 ==2:
        print(f'{p2_sum[v1-1]} 증정드립니다. 내년 에도 잘 부탁드립니다.\n')
        break
    else:
        print("숫자 1 또는 2 둘중 하나를 고르세요")
    

print(f'{p1_sum[v1-1]} 증정드립니다. 내년에도 잘 부탁드립니다.\n')


del li1[t]
li_for2 = li1
del li2[t]
li_for2_B = li2

z=li_for2.index(max(li_for2))
u=li_for2_B[z]

print(f'축하드립니다.{u}가 {max(li_for2)}0000원으로 연매출 2위 달성 하였습니다.')

while 1:
    
    v2 =int(input("2021년도 매출 2등상품은 (1. 백화점상품권5만원, 2. 외식상품권7만원) 입니다.상품을 고르세요(1,2): "))
    if v2 == 1 or v2 ==2:
        print(f'{p2_sum[v2-1]} 증정드립니다. 내년 에도 잘 부탁드립니다.\n')
        break
    else:
        print("숫자 1 또는 2 둘중 하나를 고르세요")
    
print(f'{p2_sum[v2-1]} 증정드립니다. 내년에도 잘 부탁드립니다.\n')



# A브랜드의 매출 신장률
a_avg=((a-f)/f*100)+100
# B브랜드의 매출 신장률
b_avg=((b-g)/g*100)+100
# C브랜드의 매출 신장률
c_avg=((c-h)/h*100)+100
# D브랜드의 매출 신장률
d_avg=((d-i)/i*100)+100
# E브랜드의 매출 신장률
e_avg=((e-j)/j*100)+100

li3 = [round(a_avg),round(b_avg),round(c_avg),round(d_avg),(e_avg)]
li4 = ['A브랜드','B브랜드','C브랜드','D브랜드','E브랜드']
x=li3.index(max(li3))
y=li4[x]

# print("="*100)
print(f'축하드립니다.{y}가 전년대비 {max(li3)}%로 신장률 1위 달성 하였습니다')

while 1:
    
    v3 =int(input("2021년도 신장률 1등상품은 (1. 백화점상품권20만원, 2. 외식상품권25만원) 입니다.상품을 고르세요(1,2): "))
    if v3 == 1 or v3 ==2:
        print(f'{p2_sum[v3-1]} 증정드립니다. 내년 에도 잘 부탁드립니다.\n')
        break
    else:
        print("숫자 1 또는 2 둘중 하나를 고르세요")
    
print(f'{p1_avg[v3-1]} 증정드립니다. 내년에도 잘 부탁드립니다.\n')

del li3[x]
li3_for2 = li3
del li4[x]
li4_for2_B = li4

q=li3_for2.index(max(li3_for2))
w=li4_for2_B[q]

print(f'축하드립니다.{w}가 전년대비 {max(li3_for2)}%로 신장률 2위 달성 하였습니다')

while 1:
    
    v4 =int(input("2021년도 신장률 2등상품은 (1. 백화점상품권15만원, 2. 외식상품권20만원) 입니다.상품을 고르세요(1,2): "))
    if v4 == 1 or v4 ==2:
        print(f'{p2_sum[v4-1]} 증정드립니다. 내년 에도 잘 부탁드립니다.\n')
        break
    else:
        print("숫자 1 또는 2 둘중 하나를 고르세요")
    

print(f'{p2_avg[v4-1]} 증정드립니다. 내년에도 잘 부탁드립니다.\n')



if s==m:
    print(f'★{s}브랜드가 2년 연속 연매출 1등 달성하였습니다. 10%할인 백화점카드 증정합니다. 다시한번 축하드립니다.★')
# Out:
# ※리스트 안의 각 숫자는 1월부터 12월까지의 월별 매출입니다. (단위: 1만원)
#
# 2020년도
#
# A브랜드: [1752, 4742, 7901, 586, 6821, 9616, 2428, 6418, 4492, 9052, 8395, 3240]  20년도 연매출은 65443 입니다.
#
# B브랜드: [4141, 2947, 1888, 9607, 4536, 2649, 3076, 9603, 8910, 9882, 7509, 951]  20년도 연매출은 65699 입니다.
#
# C브랜드: [5235, 4937, 1457, 5315, 6281, 7681, 9721, 579, 3630, 2332, 9794, 818]  20년도 연매출은 57780 입니다.
#
# D브랜드: [7967, 5740, 5326, 6922, 3297, 8046, 2615, 1258, 552, 2229, 9920, 693]  20년도 연매출은 54565 입니다.
#
# E브랜드: [8589, 3781, 7685, 1860, 6526, 8796, 3825, 2231, 1908, 7009, 7810, 3692]  20년도 연매출은 63712 입니다.
#
# ...
#
# 2021년도
#
# A브랜드: [2564, 9835, 7256, 7536, 6041, 5263, 8859, 8055, 4175, 9203, 8632, 3804]  21년도 연매출은 81223 입니다.
#
# B브랜드: [2054, 3745, 4489, 4596, 4022, 7407, 3543, 7477, 9451, 7588, 1036, 5128]  21년도 연매출은 60536 입니다.
#
# C브랜드: [8655, 6017, 6144, 7897, 3200, 647, 9835, 3043, 9034, 8516, 9762, 1574]  21년도 연매출은 74324 입니다.
#
# ...
