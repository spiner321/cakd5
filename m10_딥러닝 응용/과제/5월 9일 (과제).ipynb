# %% [markdown]
# ##### [과제] 네이버 영화평 감성분석을 Bert의 bert-base-multilingual-cased를 이용하여 수행하세요
# ---

# %% [markdown]
# 완성한 데이터는 5월 9일 (네이버 영화리뷰 감정 분석 - BERT).ipynb에 있음

# %% [markdown]
# ##### [과제] KoBERT를 적용하여 PyTorch로 수행하세요
# ---

# %% [markdown]
# 완성한 데이터는 5월 9일 (네이버 영화리뷰 감정 분석 - BERT).ipynb에 있음
