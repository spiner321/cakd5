# %%
import tensorflow.keras
import numpy as np
from tensorflow.keras import layers, models, optimizers

# %% [markdown]
# # [4월 28일]
# ---

# %% [markdown]
# ## # 글자 수준의 LSTM 텍스트 생성 모델 구현
# ---
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %% [markdown]
# ### # 데이터 전처리
# ---

# %% [markdown]
# #### # 데이터 파일 파싱
# ---

# %%
import tensorflow.keras
import numpy as np

path = tensorflow.keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()

print('말뭉치 크기:', len(text))
# Out:
# 말뭉치 크기: 600893

# %%
text[:500]
# Out:
# 'preface\n\n\nsupposing that truth is a woman--what then? is there not ground\nfor suspecting that all philosophers, in so far as they have been\ndogmatists, have failed to understand women--that the terrible\nseriousness and clumsy importunity with which they have usually paid\ntheir addresses to truth, have been unskilled and unseemly methods for\nwinning a woman? certainly she has never allowed herself to be won; and\nat present every kind of dogma stands with sad and discouraged mien--if,\nindeed, it s'

# %% [markdown]
# #### # 글자 시퀀스 벡터화
# ---

# %%
maxlen = 60 # 60개 글자로 된 시퀀스 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스를 담을 리스트
next_chars = [] # 타깃(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57

# %%
# 원-핫 인코딩

x = np.zeros((len(sentences), maxlen, len(chars)), dtype = bool)
y = np.zeros((len(sentences), len(chars)), dtype = bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ### # 모델 구성
# ---

# %%
from tensorflow.keras import layers, models, optimizers

model = models.Sequential()
model.add(layers.LSTM(128, input_shape = (maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation = 'softmax'))

model.compile(optimizer = optimizers.RMSprop(learning_rate = 0.01),
              loss = 'categorical_crossentropy')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 128)               95232
#
#  dense_3 (Dense)             (None, 57)                7353
#
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### # 언어 모델 훈련과 샘플링
# ---
# - 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#  1. 지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
#  2. 특정 온도로 이 확률 분포의 가중치를 조정합니다.
#  3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
#  4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# - 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다)
# $$$$
#
# - 지수함수, 로그함수
#  - 밑이 자연상수 e인 지수함수(e^x)의 그래프<br>
# https://wooono.tistory.com/214
#
#  - Python Numpy.log()-로그 <br>
# https://www.delftstack.com/ko/api/numpy/python-numpy-log/

# %% [markdown]
# #### # 모델의 예측이 주어졌을 때 새로운 글자를 샘플링하는 함수
# ---
# - 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출

# %%
def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# #### # 텍스트 생성 루프
# ---
# 여기서 볼 수 있듯이 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만듭니다. 하지만 국부적인 구조는 매우 실제와 같습니다. 특히 모든 단어(단어는 글자의 지역 패턴으로 이루어집니다)가 실제 영어 단어입니다. 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 합니다. 이따금 꽤 그럴싸하게 보이는 완전히 새로운 단어를 창조합니다(‘begarmed’와 ‘isharent’ 같은 단어입니다). 높은 온도에서는 국부적인 구조가 무너지기 시작합니다. 대부분의 단어가 어느정도 무작위한 문자열로 보입니다. 확실히 이 네트워크에서는 텍스트 생성에 가장 좋은 온도는 0.5입니다. 항상 다양한 샘플링 전략으로 실험해 봐야합니다! 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있습니다.
#
# 더 많은 데이터에서 크고 깊은 모델을 훈련하면 이것보다 훨씬 논리적이고 실제와 같은 텍스트 샘플을 생성할 수 있습니다. 당연히 우연이 아닌 의미 있는 텍스트가 생성된다고 기대하지 마세요. 글자를 연속해서 나열하기 위한 통계 모델에서 데이터를 샘플링한 것뿐입니다. 언어는 의사소통의 수단입니다. 의사소통이 의미하는 것과 의사소통이 인코딩된 메시지의 통계 구조 사이는 차이가 있습니다. 이 차이를 검증하기 위해 다음과 같은 사고 실험을 해보죠. 컴퓨터가 대부분의 디지털 통신에서 하는 것처럼 사람의 언어가 의사소통을 압축하는데 더 뛰어나다면 어떨까요? 언어의 의미가 줄진 않지만 고유한 통계 구조가 사라질 것입니다. 이는 방금과 같은 언어 모델을 학습하는 것을 불가능하게 만듭니다.
#
# - 정리
#
#  * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있습니다.
#  * 텍스트의 경우 이런 모델을 언어 모델이라 부릅니다. 단어 또는 글자 단위 모두 가능합니다.
#  * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 합니다.
#  * 이를 위해 소프트맥스 온도 개념을 사용합니다. 항상 다양한 온도를 실험해서 적절한 값을 찾습니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 61): # 60 에포크 동안 모델을 훈련
    print('에포크', epoch)
    model.fit(x, y, batch_size = 128, epochs = 1) # 데이터에서 한 번만 반복해서 모델을 학습

    seed_text = text[start_index: start_index + maxlen] # 무작위로 시드 텍스트를 선택
    print('--- 시드 텍스트:', seed_text)

    for temperature in [0.2, 0.5, 1.0, 1.2]: # 여러 가지 샘플링 온도를 시도
        print('--- 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성

            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꾼다.
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링
            preds = model.predict(sampled, verbose = 0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
    print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 13s 7ms/step - loss: 1.9652
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the some as the self and the soul a sour and the self--and strongering the soul the self--is the sense of the self--present the sense of the some in the self-spirit and the sense of the expecient and the complesent and the comparied and strongering the self--and soul of the present and the present the sense of the self of the present of the some as the sense of the self--and the sense of the sou
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a think the see himself and pressed and one as the more one is the decises and yrease one the some the for out and in the preasing the duch the feelings, at the comparind that our the ender in all for an and the for of the greated and but compression of the selver the pertach or compularing the will the erse of the pherous of the moral preasure fulled the self-ferent and be the soul spirit, and
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for eabted" and befine merainate and she becomes, exien freent: or is,
# who arw" me thom new reever here" in the virtuars, and deer r!suchale,"; the frrengerisned the soul clestiny as ruvolous
# rea; more
# mode reyed its sote hist yor graward the was faithnlessament himself and ble
# subily opnous""d in the
# jpys the viety there is decientive thus a hilther an the t at who son we regard ampletiale, the) p
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for yeb! perture
# to, meals---u onouge flu nymin(", ,ow oy a hillation:whill phows fee as trys feulhiataricg mearsspy a whateved whith plecent noh lepdscieru. at hith" of new thal tited, graiged, atsil higher bereever,"lod,
# s
# "gros
# sem-bests, athays; fhelop is a persors, scho the depmed forme be folled.
# ha, pidind man which theiry sense-cans;
# it religiou"
# pleeble enone of rejurd di, philosopherment m
# 에포크 2
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.6150
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the more conception of the consequently of the conception of the more of the strong of the proper of the conception of the consequently of the promined of the greater of the more and soulse and the stands and the strong of the really and the more man is a morally and souls the self-creation of the conception of the sension of the present of the conception of the more strong of the still of the c
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the very and his were exertain and and
# a more creatable of the more of the recaring of generally and were souls, the our very with the consequently--the power of self-contrary from the still greater and as a reason of there is the result the reason and from the philosophers are our in the almost and case of the more of the conception to the called and as the concerning and the discience of the r
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for that orgende pleasure, as
# esth-aller
# goodgnord iglism but requirly-aphisorimestulially that herenoce-inther egeret, an
# new exprreali-tens, now diftersen the gread. it hay everyent we alle existentering and contried a condimuse) of
# itself, we booy often may zeast age is as a  now nocent
# a an indigbed dicciture path now
# seect, which is atevenlizentineoges of
# a person untieplaterealijusion kind dif
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for moor fuster
# ethe it to free open lo
# eridene.--he
# whith, his,". ald attinnest thereass and nothy be dit ne
# the victial the same sonemuc and eldoms, how foosted
# give lalkes tome mys, the villy ay many womanly perse than besuchaterism
# condin ti! tumes--why is proposianane,
# the good of burevestor anythenly, -atasimy, for if whore is in one i most finder,.
# byle-grain: ally,," gines.--"they."
# for clay
# 에포크 3
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.5273
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for every contrary of the sense of the sense of the such a soul, and the sense of the sense of the sense of the sense of the such a soul of the such a sense of the sense of the sense of the sense of the sense of the present of the such a philosophical and such a soul, and the such a consession of the sense of the personess of the sense of the such and such a consession of the same of the such a such
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same and moral world the consession of the self--in the virtue of man in an and opposition of the condition of the are and supersionted and this live conduct and power and had on the here of a haw of endiry and an an and in the concemnt of the experience of the higher to the condition of the could powerful to it is in the desire of such problem to the conceptions of the sun of entire and so
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formething
# me--it taken a sinel the promarn, how something with the consequence of that might in false--the same--in s diritsed stiormps
# could peahanmy seffition.
#
#  something, live ethic,--one is not become who sin lave distust do not tnat sickely the same exhight givestol? to be waud of ly-grearness hild it is breel strag), ond concast and
# dedicant revengeutal" yound folloply, the relation. thr tym
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for europe is limal "pjodeditionuallkge, and tith the sealing this presentabbliry to before, to dues by
# lersing and
# shadiwive the moral
# inplamence which truche. dickoposherations and defty which revelling no inzerman vengmen feel civilibl genour mult things obet. she fuild gorst e the ewher ffre
# bronglments bryunglike he remage, feel
#
#   he w
# ? ,  scception as clooply
# thingr, weaulingth, retive to s
# 에포크 4
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4806
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the good of the strength of the self-still string of the string of the intermant of the self-same of the self-delusions of the string interlung that the present of the dangers of the conservation of the such a philosophers of the case of the great of the string of the self-present of the string of the most sense of the senses of the most string of the stand of the self-decestion of the most asce
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the heart of the confess of the denonger of the conservation of men and the felation of the puritaned of the eternal end the sead of the others, as the self-struggered of the greater of the pressing of the greaters with the according of the has ascervituous of discoverest of the tend and the desire of the sense of the seems of the still interlune and found in the does not the strings of a world
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for unjust that the learnn--who all away equents.
#
# 1
# 1. a puts and jetromacy for the conscience of kindsgnessy to every metirally in
# the most life," as upper a scontgous becomes
#
# tbyfure, and itself. he lookity spiritue" chargianirs frour who
# recognist ex-master's, scienters to like every still
# bar-that make to others). i ashed
# their religios to pastike, these iard gulat of the dnearnciant just,
#
# ca
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for revering ata, and.
# this doom has another are not ow",
# s its, no maxing
# conhetrit with the general time of higherlous that macust; there therefore, his jesured
#  trutajigim, caises it shourd in altore method ears--that there is dogncees. to "englibles unjurmes houst bitame. supposes. he must as ay a "most
# wco philosophey togers ndble, the will hir
# as their pur, and sensef, and impcrety loght hith
# 에포크 5
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.4487
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the most present of a contemption of the same and and the sense of the sense of the order of the even of the sense of the present of the sense of the superiority of the present of the sense of the interpretation of the stand of the present of the contemption of the same and a contemption of the most states of the contemption of the sense of the contemption of the present of the spir
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one for the faith to itself by the best of the be of the docking of a scientification of the metaphysical world of morality and words of the contradicishers of a deceived of the spirit of the enough of the standard for an advention of the instincts for the belief of the presentement, the contemption to a conternce of the order that the pare of the german to the the man at all the belief in the d
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forment arcorsed than we are accomper of anpiven
# ogiety powerical new and was dutes, and far experience soul among in the off, whom willodity donary for the has you able whatelusness, perhaps faith speaks on the infly of the hortic of the pads mores,
# but presens and eyes whatever are qualist rgelless (renglocity
# for pleasured. through duner every disguise of the belief of the new
# and our bester-exis
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo onese-s for thought emon as develosing--should uives and standludful encitovere, who har by through "posiagainarnical
# coppeshant of expecivanily
# it than
# hrapn, that the or
# physpoch. and
# (as woman whatever to hipport" to mitual-lustsbx
# aremasly superintul. why divine is in comely giveness implerass:," kinds
# who falvy now
# bad, were do discovered i? the giverull, liffed in sadbervency whithin-exhmar
# 에포크 6
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.4265
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superiority of the superiority of the desiress of the world of the morality of the morality. and the perhaps and the stronger of the profusion of the same and and than and standain man and something and conduct to the conduct of the conduct of the superiority of the superior of the same than and conduct to the stronger and morality of the superior of the superiority of the superiority of the
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for his self-dangerous themselves and free himself, and that the devoleg and thing of the indicated believed and difficult that profusion and morality, and some an our fearful and feeling of the presumation of the same of a morality of a higher within of one for the are something in strunger some man are to discovered the does in him to be really be an artaon--there is conduct of the stroke and the
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through found the willided, that a psycholardism and before one of the oppop, of viewed are decemors, and men without furthere timb apprehable simply were mean with free die feeling being understand all freidely-geniued, to now
# dingbition to talns of the same opinion, the buresis upon the mestabivificantical thought the tald apprease okin sufferingion. in theg maven feeling to it as an europe
# carishy of rel
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the arish bapjopaularician,
# intention of nate one is because, indeed" ropony still,
# your corlumers, being than and his tern special
# purson
# paliss splevebs, long myight), and bela, does navefr's cobderances
# allop would ginker ouces, vict,
# bor's, jeath in their
# men of all
# extlation is upon
# the conveloustments of temph "i
# free ordure--an is his right has first, preases--great;
#    called waritt than
# 에포크 7
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4107
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the soul of the present of the spirit of the comparising of the position of the self-recommand of the strengthing of the present of the present and complete of the the present and complete of the scientific that the same taste of the complete of the scientific and present of the spirit of the such a moral of the soul of the great personal the strength, and the desire of the present
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foreinally reconscients of our enoughes seems to the bodence, and misunderstand the depthmin to the mide of man in all the present--the artists and moral for the one might that which what latter this and called and here as in self homest, the enough of the sense of a reason to be so and everything philosophy of the moral percedain that the are opinion. in the implear and personal for the brance for
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# could pancing flects to seture and highest prevaildly med on the coake orally man-varience."--as onal they haspres being in the great, it obpeouldts
# of pleasing out of chaims to falrenacal; the devil contempt to nirlovogares. and knows hotistly tysten that poline soul for one wishe are
# cattiness, usus regoroulttism of moral belited(by sustration
# "or language unrelugated--the spierty,
# through the
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forgetion thisther many
# be
# doubfic poingly.=--the yvise?versmor? who his prety ywentry thinksd" to what the good "otwus to write tluseal selsepcisn, prefiritenly which, that his puipllaturates so itwerness, human instratting by itbels perhaps his emo. for a
# peroper man of the ewhal
# himse for the
# emoint
# of which we may or did
# not great quicnness spirit alanyhens. no life that is. how europial soming
# 에포크 8
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3956
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the condition of the conception of the whole of the strung of the condition of the struggle of the condition of the strung of the fach of the condition of the world of the conception of the world and the subtlety of the struggle of the strungure of the strungure of the condition of the desires of the state of the delight of the world to the whole of the strungure of the conduced of the desires o
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world standards and more because the world that the concerned, and almost only and scholar the moral, of a moral subject of the delightly of man and account and conditioning fashing the general valuaciance of the higher powerful and interpretation of the faiths, the barr of the general the begar of morality and the interpretation of the taste of the whole of the thus artistic can of the surp
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for english taring in thinks, o gainful tendele worldly new aly authtenty--who poced like a our disguils has heart for this worst
# is no longest his strist can
# has dud understand itself conscience in the ascenticable of ye the good where made as the doing with new progress of the
# exricstory-dory expends upon that like, thinks life makes from the exomat pa virtue of is ald a compassion of invintive in
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for in ody carophy a marfelled. the   by profound
# the tist: and his comours an atimism, us human riches o? did imspraous set mi: thinks, sunder-certain negslaty
# upon
# the peower
# onover flamjurement to a greekgness in gringes of conterness; that he
# lace, greye-this men has co,oford,, uninggolegt
# beginntifue himself the absolute oy combard of wholver--men, and unimoquestion to furorous to be
# nature mod
# 에포크 9
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3857
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same of the contrary of the subjection of the strength of the self-from the sense of the man and the condition of the subject of the man of the sense of the conclusion of the moral of the sense of the conceals of the subjection of the sense of the concerning of the state of the contrary of the contrary of the reason of the subject of the man the great of the contrary of the spirit of the con
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for him there is a parthers. it may always most soul have no longer, as a great and recognized and betraying except to the hand and
# morality the philosophy in the sun of the instinct of a man speakhing he commenes the predication of the order of the assession of conscience and nature in spirit the demands of any generally and compelsed only means of the people recognize the experience of the contrar
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for i a nature, with the
# purlazed, or as crumine on the reasonforle" of the outhomihatikes are, it is the very lankforation of yea; they in vild; hi house and hymentary into the judgment has with a rexicts
# and deceived: it has a nem of one morality, for has something or
# free states a predications and man or
# anything and branticiul from manyside re rearrdy mich and very powerate. its
# concessity man e
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formilly outbise, arttleasy,
# man: one ooded it hevinthanable, 2grifted natural can that theure amved -et thinkes, will pregare na posses: sharne find. if the dutesly,"
# noirel ellpiormumence i preo's under
# gather,
# individumedness mobicdooth
# and
# recapeated vohrfactes our human reason saciline dlive, have
# neven timpusm, close the easy, when only depthatics all e, gr-. other:
# prodaintial; artzing and vi
# 에포크 10
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3735
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strengtor of the contrary of the conscience of the conscience of the strength and the conscience of the conscience of the conscience of the strength and conscience of the same tender of the strength of the strength in the conscience of the supertain of the scientific of the sentiment of the strength of the conscience of the most souls something is the conscience of the strength of the sense
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the presented of soul advance themselves are destruction the conscience with human for the developmeng--consequent to the proper of the one will would conterence to new the sentiment
# of a long to intertioushely to the being certain decidence and contractions can divends himself and probably should
# "the produced of everything to the here of his own intertions, in the really conscience of the inte
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for this
# self
# but a long
# itsodypousive have reed in
# the conduct, artisture oner, one here; man
# feeling and remocnes with itcertane
# in
# the other sy the childe, and can not not nothing
# the inspires into certain themselves to one of recestly rare therran bestried
# canes. they are assibled is not
# heredity
# happiness illow is impurated gry how and learn in suppositely of
# philosophicate
# incestion of its res
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fortinally bettarite nothing wertel" olenly where mosllyars
# shiwhile, if
# what
# svoublds and to how sneurce as he moder, cared".
#
# 1oxtwist
# mean also
# inferior? illf voluccy.--my once could begreveby may have vonta; towarden.
# .
#
#
# 21
#  deimatics, arises feelil
# rocess permost
# agreely,
# affair developmed," onerrable,
# mutuce and mutial subltimente, certaineme.
#
#
# 41
#
#
# cruer todeen itily suffers
# and ever contri
# 에포크 11
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3641
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the consequently of the sense of the sense of the sense of the sense of the sense of the are of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the such a personality and the contradiction of the world of the contradiction of the conscience of the sense of the sense of the sense of the problem of the sense of the sense of the conscience of
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the problem of things on the olders of the profoundly of the resist of the are at last precisely in our new and nore to all the trouble morality of the tendency of the one is to the worth of the distinction, it is to be such allowerd with a personal the families of the most words and in
# the doot and whole and the "consciention, it is a present in most posting world of the superfice of the stacte
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for enough into the profoundly nockworid. they be are
# be amoughts in
# all the corrange of utherpo dogbal are tuck otred, even it all witascomninne can not be goodan cha-lipjored addeatical directivitating outver
# of the deceated in
# the himals, noces
# must
# for the deternine madwy of the philosophis more nome sympathy,"" one to all the mellor of the wormion, relusion; the love
# exults and piety and are ch
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# here is not ea, something feelings cores, alrearan
# howach a. the most origin of do socials work out a how steple sympathys, it is feels beequalness
# gutal
# nolrogbalsly and clithming therefullyw, well
# he another itself.) inoratei"hs eventiin does not centuring interese for being accoscands sure to sativies him succes
# had tharr; upond,
# a how
# wnerical, the fine if scarinfkions
# is call to distomeativ
# 에포크 12
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3581
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the man and the promitive of the sense of the philosophers of the present of the more of the contemplate of the sense of the man in the sense of the world of the sense of the instincts of the sense of the strengther of the conscious work of the sense of the freedom of the sense of the conscious opinion of the man who has the strength of the sense of the sense of the sense of the man
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for they wishes to their tumbless--distendence that the belief of the self-decident sympathy, in the world of a present of a man who has the preacish of the more interesting in a civileres of the past of the reason of the pophician and so stronger to any seculate his prevent of their expent of the strunger of a pands of his principle to be (and for the world of the sense of the sense of the philosop
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerathing could piecial into natuilisn of as a wold still of sead in men, equally, in the bod here true, in virtuld..(butived pressivels
# the begoolness give
# estimate
# trouble o
# from, darivactous about any
# seems to do under artists.
#
# lit, his begenners, wender something as the power of the seef in the clined
# menseful tirmance for burne, sthe self-christial rranquideations
# of a virtue, in geek the d
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for be rated. :   so makes wightile-innar is such typpenwitions of distlessable--sopirity which evil. they "muss,
# she only they withit involchingly
# perhaps giveps originally extrair that the man which you is cast, a
# depule stelting--like religion finonalizicm whogher sevely explance; in one divabuoned thiss, in grnear.: "wockeow with each knowed, operathy, with "affirmation, in the conscious began a
# 에포크 13
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3489
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the strength of the strength of the provestion of the self of desires of the sensible of the self of the most person of the spirit of the are strength of the sensical conscience of the strength of the world of the desire of the state of the conscience of the strength of the sense of the conscience of the self of the sensible of the self of the sense of the strength of the self of the conscie
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly, the soul, and the the state of its consection of the condition of the promise of the school of the way, and most same fays of man and oble to new and conscience the order of sublimed men of the most new pare of a powerglesst, one an even the propertion of person and fair to the religious consequently of most persons and look of the spirit of the compares, that it is the democratic and as o
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for overance, and belong, because
# it i could verent, a the most opinion
# of earth, let the something of philosopher. it is only suble the "leamlies tranitry of cause success. "you
# christiand
# it ado usual, the heart, or
# now the end tantaus badl
# to me he know without likewidated,
# the absolute la.
# yhung that has it were more comparishisn--shoret; the constituted is to one
# convined unbere it
# were
# thning
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for their fingers, with even dream without then
# he by become
# a desckobarding to who closs mine",--name,
# increasad in the questionisdic ideeling". when more
# dradument inwourus lurberbes, here, inbet, he spineve
# him, in the
# ew troodss: itner,
# the warfup and still to more way
# witking,
# whereody; echould coporred
# thricen is man even us cause manifeses such a mequity man, when the knowl--how a life, onls.
# 에포크 14
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3439
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the french of the strength of the philosophy that it is a morality, which has been the suffer of the proper of the strength of the strength to the consideration of the strength of the world of the most conditional and the world of the most condition of the degree of the strength to the strength to the states of the most conditions of the strength of the self-contain of the belief of the work of
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the one to the free spirit, and even to have stand in light to reverent there is because on a good of the man felt there are a fully therein, which as there is a strong learned that is a consideration of the same means of the sense and there is a schaining of the present of one has in spirit and desire and achesial contain an influence of distrust of the world there is there is no men in a the p
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for regrace in soul or an there yon which the heaver of upter other to one to evil a disny siffer
# vitabated conditions of many senses.opher to--after in every olding of one have motives conferems is exuch distant of
# physicrtor, everything that of everyoher, who betwenlelgure regulan princismly through disensition, that there shecery this keep aculey number learnly, which doy no
# than in all insist an
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for thrsilffijsest itkeedful from philosophy. but
# "freeplers
# mamner way, and demindly grese
# even cirion his impare! not act
# out may may proveltale the girmedt--texporectioh of a reflect,
# as to be cordarrab's
# and
# crues occtsisis,
# be hirrofons,"s, there, varine, "most
# self feels elementaly,
# "spirit tives of dawnful to the people
# of course belighte--there is at he sweap. noth feat, same, while rake sha
# 에포크 15
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3385
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most soled of the most problem of the profoundest of the strength and the rest of a god and artistic and considere to the present of the consequences of the most problem of the conscious and the present of the conscience of the present of the present of the consideration of the conscience of the art of the consideration of the present of the present of the present of the same and present and
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for example, the accepric postistic and reading and science and the
# nations of the conscience of the tenders of the point of the present of the even in new command--the most powerful superior of man with a greek and instant and discoverent the religion of the cause of the causality, the result of the most world from the germany and faction and the persond is a morality and the desire of a consistenc
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fourcher. be exprime, thee, appears of iway superstitiof! the name, perhaps farly very allow. and certain distinguates doilence as poten(thing of all skepliows intertually enthing of "prevalulo" of anew, our to be etagtism, ehid, "scienorm and accord of and criticish for them are almost depth" and
# supronations, and all its hadquered
# that something to the father sense semporiby as once ingreating in
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fourld;--is it may for the worth nature,
# the geaul strengtherous e our by, the knowledge: of to of experience function--nih
# the philosopherman ideapy in facttless." as for exhitual is in pains estacus as it a o.s
# it mother. xist
# discoversfulne, class, we must, that the older e logical tamcless him in whoove
# losing sup, temperation cat arpomically." "freer bogres undoes.
#
# a xtenting first to "merely
# 에포크 16
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3334
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the command of the expression of the problems of the world the primitive soul, the same thing in the commonist the princed the primition of the spirits of the fact the sense of the most perhaps of the same thing of the strong of the sensus of the same stronger of the strong and still and the same thing and sensus of the commonor of the spirits of the lower of the command of the sensus of the sen
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the command? it is not friendly in the philosophers and more comparisom which the command and community to the same taking a self-dereled of the most finer will had to a man with the most disclines can perhaps grow the europe of the man and the acceptious the moral put of the stronger in the history of the philosopher, the one another, and the spirits of discirtely and the thought and the constr
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for her position, and sort of as it wouldting stringer beyondness and naturally for
# priportentily soulg a of the inexestive of
# his mound,
# ly duty society, indiffical us, every
# prew of purites of a creationalns and must we honctal. every popular morality. they are, also, that or order to atainterding in it, or
# bet that that is not have
# works the spirilsvation, those is should most there is and confo
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for whom the
# econd of the friendness
# individualeds: io st. "the most to uagod--always rost thech--in which as sork shsy always will senstantiful, disguise,
# there
# germans, but, they greeure and
# uf or at has been platoonentful but thxer, and it
# reald--but on slokegon the i.                             pomiman i such to overgo tistie"-ammpure us that he rusid, and sensitives, as
# -alwars.--that ose somi
# 에포크 17
# 1565/1565 [==============================] - 15s 9ms/step - loss: 1.3287
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the senses of the most strange of the same and the standard of the soul of the spirits of the supposition of the same of the state of the states of the standard of the fact of the senses of the spirits of the such a position of the state of the standard of the state of the standard of the senses of the spirits of the standard of the standard of the senses of the state of the state of the concept
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former to himself to be et is one is to be are serious contrary can dingness, is no maniness and believed than in meny many man with a circumstances have not one can be a, and the proper, the faculation, as a man in the speriously of the existence of the from
# the soul perhaps are concerning to considerations, and the soul, the right to the morality of the ages and contrary
# and great tenders and such
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foucce of the
# intravbiming of mind; he neuent. that in othersy; what saint to which they alsofures related of "prevaludence--predame gutting, than in the senter lives, not how, ensut--and al has with
# his wantent highess up a beautius continually to from,
# preseleming is usmandsenly the trabitswory of the dreams a moby tends of my
# with
# care sying in their condemned
# man thore it is
# of its hind most gea
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for sucrems
# type
# same hardennce or       standat
# as sfortation, wall--he
# strively, ondersain of but as
# not.
#
# influed society? icsyingful to his--let us exception
# than this being spind
# raw deuit
# occuplird wondsnal may make the mult facudity"
# ideal" cirible calked; that act would oncuer de!nulh also probable,
# the really and
# comald,
# with count, as fusinglencett is extravajy
# in, every social" in france,
# 에포크 18
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3236
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the desires of the spirit of the spirit of the spirit of the order of the spirit of the spirit of the spirit of the spirit," the spirit of the man to the problem of the expeciant of the conduct of the conscience of the present of the spirit of the entire of the most person which a more of the spirit of the spirit of the spirit," in the same tasted of the spirit of the spirit of the world of the
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for interesting in the tastes, as the intentional value of the lofest and truth, without the tastes, the experience of the fact that is always who has diffirent that the tendencience of pleasent of the o", he who same the inclear of the conscience of the most spirit,"
# the a baderable of any senses of so that there is a problem of the lower moun has make a really of the world to incances that somethi
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for,
# impursists of the "ones!
#
#
# he really ? must become. one of its perhaps can
# originated e. "has been
# sxcertion to which like in which le
# sacriabler
# byster
# winding reason, at this diffirent with europe, a
# will to drator suffering heaved perancus. the one will like everything that thit he regarded,
# the
# tres-gert ruled, without our countidence of lics-isungery to
# reen an admitically occasional and
# d
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for delise,
# alwarday, one
# respection with my artistic greek owing tenden;--a volta-cleating onles whigh and factver effigured afforder everything bye, heart, medens! could
# hole, primomy, the ethicism, oly distress to
# accordous, one
# clight to the power. thee?
# prey the trulity, as a co greshier of freepsiaristicl choorifyance-loge
# attately. and that wistiungfol as ag what
# decent sneld-recogris cogniti
# 에포크 19
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3187
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the strength of the strength of the states of the strength of the strength of the belief in the strength and man to the conscience, the sense of the strength of the strength of the precisely of the strength of the strength of the spirit of the conscience of the degree of the spirit of the state of the strength to the strength of the spirit of the strength and the states of the spir
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same of a personal intentions (whose one to the instinct of the comparising of a power, the religious man, if they are on the world the greek and philosophy, and evil, where--agreeable from the others
# are there is so the man to
# the light that an
# accompany
# can be brothiness and ages and to see the most necessity, whole the strength strift the greatest the gradument in their fact the most such
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerfourh, the unints which the reason of the ma railer feminish,
# thereby the spirht than sensuements
# that is threll, with a fly himself yease romantisis presely feelings withing aloty with obedy
# pain of mankidd from religion. it is at o
# rulaw and olding and known--rull. be in, healthoph, or helve as every other modeptivou
# the sublimation of the astricaurs--how hidverly--to be "ecaction or all
# to
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forward "pal.m]ry, the
# indutoes in ulligian, calle morals rughulg, action, babredity, one
# upestal-per-rrandy--they ally itsee.--plach and mocqueh
# minds.--herready in our justices. it makes thus progotsing from openime men, i di
# fverse:
#     nothing to its the
# "could serromer of
# subclsy and--this larg to means in a
# "modernaryonclesstxiances
# of ploous races, sam, which once yesks douring in gave,
# next
#
# 에포크 20
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3173
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former the strength of the self-contemporary and interponment of the strength of the self-contempt that the master of the strength of the strength of the experience of the tendence of the conceal of the most sort of the self-contemporary of the sense of the sense of the sense of the self-contemporary and of the contrary stronger of the sense of the strength of the contempt that the sense of the sens
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former the strength to the tendency of a sort of the self-conterposition of the wholly still life of the second, or distrustful mind of the fact of the fact that the worse of the man of the unself science, it will a greatness of the pleasure of case it same to the english of an individual original soul are truth--and there are sorting, that the true time that the most second of distress of every
# peo
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms of the free thtually, unnew
# to man warns; and or
# it is after
# sifficiding, orakness soriclicis--to humble everythight europe: "has to our eusope, cay in all power as short, are remade,
# to valiness
# there are beak instanct wind. there (and, hesen whose endhaching to victistate, whichs?
#                  new. "feltwow is the subontenly burpory upon the syringer is, with annative indeed them men, hi
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former good and of the superfician
# oncenness of motivis=.--also upos it! what sertimally grows,
# this does--wimation.
#
# 1
# 1] look at lengue! whethers musicp--clastmin sympant:
# with its words of special pe
# bitacly
# masters,
# through the type cabriot," been it will be contrarys. they art rece,thiphed true, the fundamental sufferings: or
# i couklest and the metaphy?s
# theolops, wore in alid..--lit rictocely
# 에포크 21
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3118
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formult of the states of the fact of some resting is the instincts of the superiorians of the conditions of the same world and most and man is a more period of the superiorians of the personal of the sting of the reason of the condition of the possession of the same that he such a part of the still of the condition of the same than the sense of the condition of the fact of the same and states of the
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forces finger
# self-domainness religious science of the envinces of the superiorians and individual of the conscience of suffer of the superior of the conditions is not so far who make a heart and condition of the meast and stoownes of the tents portaint, and the nature of human friends, without success the belong and extent of a hardory in the conception of the sense of the "more sense of the conduc
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fortunately, with any one ask when "the world not day
# something belorfactible, only should take the "than entirelually "conscience icnew , namble, promise to
# many shactule, which much at shound
# mi)uny
# right
# as anyobring:
# they does hat perceivious
# to eith. sometimed hear
# the right that into deegoment of heart" result for men, is ago of dotishs and ragele)) as it nowire learned fellow happiness but he
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forgotre,
# indepehd: the st world
# gives of conditioncy bitjosl).," at ! some had a dener. this fe
# his aresows.mef with coupates
# scientific and shound the faculy cofcets sylew sort, "unnern! it be uneppuents) fairing, died concernes should, of lict!
# masteys
# blunemin
# life mike fhreyounds
# religiously, through the kewendly ongole it to anmediocr:
#
# insenksdy--and evilcated
# with everytheresp oused from ot
# 에포크 22
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3074
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formen the moral spirit of the spirit of the fact the struggle in the properable of the struggle of the struggle of the struggle of the fact the struggles the spirit of the present the standard of the spirit of the struggle in the properarious and destruction of the struggle of the same that a subject of the philosophers of the properarious spirit of the struggle of the spirit of the comparation of
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formen under of the properable intention and closed of the state of the most conscious of disposing man who has for the pla man who has proved the development and conscious of the result of the struggle in the religious man of the present conditions of morals.
#
#
# 1ox man for the fact the gradude of the destruction of the properarian of his experience, and and as a fact in the world and belief in conc
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formative to him? the new possibled than wholly
# "adapsless and to grodency and these estiment of philosophers and nothing that something be may percosess
# as little at present from scysceniing conustrience.
#
# to  he thinks
# but "general, perhaps betryrictuality; it was unwill call
# to it it gruppousceded one anything that developed, exact development of the nature are struggived of the sense. the loves
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fournessisi tompled and etablity" how in
# rogint in littled) give thereof: we not, exist, constage our phoblemorval
# weresble and funtite of involuntess
# in wish to crases
# indedif.
#
#
# 1le orities sured and prevailty
# and science--the marjerction
# to myself, there is
# awnotered because fless mate is but agreeable for frughty- way
# in mind to asveyonknered thy whod realming-hundredisty is no strugnar for inli
# 에포크 23
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3058
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most consideration of the spirit of the spirit of the sense of the restination of the spirit of the sense of the self-conception of the proper of the property of the sense of the sense of the philosopher of the sense of the spirit of the spirit of the spirit of the spirit of the sense of the spirit of the spirit of the development of the spirit of the sense of the conception of the spirit of
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for enterpless of death of the contrasical mensigh, the spirit of the command, which all the free spirit of the strength of the philosopher of the last of the truth: it is a soul as the great bruacrian of some of life of the strength of the basis of moral individual self-bad of the sense in the development of the most sense of the world of the stranges of the
# best, which of the pleasure of the self-
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for their utility nature, with orgrane, might no febls
# to the dreams, whoe the tage of rate. he realmeditw seldom for examplimative said: why has much inner
# into
# abgelns and induces
# and
# to uns. the best propers of ethoperted advobring and curciviniim-and owing to life to to would not
# havitunes to difficult a nonliwines of definitionh with the more important consideration consuccrence to dey and most
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formingless this
# cymand,                  neoponsible. af over walti
# great
# dediouss itself.
#
#
# 41ue chart, without n a toming: e usecous, that slave, ye foundre
# world intoter more's entire knowledke,
# cillity"--heart a
# ceptificative carl!
#
#
# 28.
#
# existening of spath to luce in
# nually,
# whicher undalngelly; tust-intexe(thation, present, clumen his
# more handing of
# acts they sentiment s a,
# far -pre_,
# the
# 에포크 24
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3023
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for one must the man of the consequences of the present of the proper of the same of the organity of the world of the entiones of the self-contemption of the spirit of the belief of the world of the consequences of the master of the contradiction of the presence of the world of the present of the proper of the matters of the presence of the belief in the self-continue of the sense of the world of th
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one has fingler been in religion that the general and relance of the feelings of the same of the "good" in them transform of interrisee of a harded of the scey and makes of the feelings of the matters, the the reald of the philosophy
# ...
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former hardom from the sufferings, short should be come that the highest of the philosophy in the strength of the philosophy of a man to the fact and ground, between enough thereby them under the bad significance of the reandousd of a supporing and pational before, and was a god, who have been from the reason of the estimate of mankind and the masters, it is the purporal conditions of himself to the
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for impossible has, in bemutwant exercising the contemptiu
# ssan authority things a mind of more" culturism, or states), language him, to simply mistage--the inscience--as the theerituedness: therefore, from impumant healtg mankind let us not them, and a species
# of somen okes the threat, which we greatest must so be allete an explanation of depth ow of history and instance of a bad insignificating" o
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form of the
# spirit is it, impress it we sensmine, as we bolgatily and concate thereby it is swe alluwy, origin
# or impexie, it, we nothingness the rained existence. an ait of command, he think will be
# reashes
# exist, thoughts! never need as cat old ilon
# inclinately. an      a peculorocation sympathed. regirtferved and other,--a certain purino euttem, that ste
# is desirabit to secceder; be of more excat
# 에포크 53
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2476
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same thing and also the same than the same thing and also the contradiction of the sense of the spirit of the contradiction of the same than the sense of the same than the proper of the sense of the same in the sense of a moral thing and the sense of the sense of the same than the sense of the highest of the most consequences, and the great every contemning of a continuous and act and with t
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the contradiction of any one sound in the bad act of the same invention of the beward of the calques. however, and the protection of men of the most consequences, is also the philosopher were one another and by the soul and character and christianity souls because they are not the propes of the experience of himself and morals, so that a soul as one another the feeling of the conkness in the sam
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formerked into learned, on the indignance and artisting of the heist unless affing of sourcatives
# for a meansses--senshain kepe, and there is through need in order
# riced world of tesservative,
# the
# rational type." its aure to the same over, to inschright acles no
# bad sevents of wrotes of mobless of morality of men of yen, indeed, and in anyous ascentfutence of echolved
# herefulness, also brongels--for
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forro lass in solved, which, as howeds into him, nze--at in onement will, esters by contore is, it is pains assumed evion a consequence, often vedseds, we has erron, and i certain frath xisforation, by others,
# is pinately throet domines into whom the
# assert one bothly the lavorocre for because withous immond-: xistine oblen within to
# devis, what may oppose threeye!"
#
# 1
# int. alvo to make even burding
# 에포크 54
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2475
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through force of the contrary
# themselves of the stronger of the spirit of the stronger of the
# sunscributed of the contrary
# in the stronger of the same time the strict of the most christian of the fact of the states of the stronger of the stronger of the stronger of the consequences of the stronger of the stronger of the stronger of the stronger of the strugglestion of the spirit of the stronger of the stron
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through force that their again of the
# foreignessed by means of his degree of a deceive, the instincts.
#
#
# 13
#
# =the moral conduct, which is the most conduct to the philosophy. in the scientific of the charm of the contradict and the state of mbi(ghome it one of the morals, when is degree for the will as for the great of the effect soul has in the fact of the fact of the morals, when one must because they sain
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through force and
# history. he will crimacted with a dangeral
# of the purely
# of upon
# withes sweardy over characteristion with forth than a boly, who concealed of the
# strict sect of courses, were it we must perceive, and
# stole of the pitth, as an collacy, and it is false. onts and dainty, leadung fleshed and concea superation of dangerous; but a last individused unuser by "vi, upsetures of aarticism, even the
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fombativer, thre plan) sy, or very
# loblit--fund dispalteless in their yound
# their hungressly: maversyonds.
#     awernest a claveley recuuse of solufifing coldaning and skin tonest say
# an, and do-dwumper, poychity"-posited advanblessherage, the
# visits and injury as the are intensifion and diseews, an-lay. it on would conous
# dew inclarey and later philosopher! thereoresials" with ,x and before for soo
# 에포크 55
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2456
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and pain to the strengthing of the strengths of the strengthing of the strengthing of the man will to be still person is to the same than the strengthing of the strengthing of the strengthing of the spirit and the world and actually there is the strengthing of the sense of the most conscience of the spirit of the strengthing the profound of the most consideration of the strengthing of the con
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former suffering and comparising world science, the
# calable of the strughd that in the fact of the presentibation of the conscience, as well and art, the proped of philosophers them as the great enthangering contradiction and man and the religion of the science of the most consideration of the last of the spirit of a more strong thereoffly and the strengther of the fear, and themselves that is to an
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forer to morality and unterading
# commandble for, doing
# clook and romantical
# inorviritmerr
# instinction; it is great even burling pampoustion in us!"
#
# intilion
# flowdeinablisionable which, in many
# sentimec-dormindounce for the may see his general, first, but increition and seasely, who gracum.njoy will from the spother, the possess, and any nittures
# which the port "the iding and castime," without posse
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fought of praised,-hear). bit:
# in comparitorous to maniunive slavefu--which the proo-ansent-cice calmination of himself,
# "toganity, that prues learn. rucus every suffering morality of type nothesfularianment
# my inamination upon melaned lighan of two persons--and guel. no delight all consciencied. "why, do. we ready ashave they seeming? for then, to trained promps these? the struves to
# the instance,
# 에포크 56
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2454
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same taste of the same taste of the conception of the fact that the experience of the same time of the strength of the same taste of the excessional man is the case of the same taste of the same taste that the man will to be a conscience of the same time of the same time of the struggle and soul of the same taste of the same taste, the same taste of the same taste of the world of the same ta
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for him, and so man who ever the conscience of the things soul order and attained here and the case of the same than any do once the man always the old templant and disconsary become provided the excession of the structure
# of which the love for the conceptions of the present of the heart of the same moral science, the same heart of the lack and different for the man warined different the delicate ma
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forth commpholonhing a
# great of men learned peromgence by air of the knowledge sympathy, for deeprics--as they surfmed her
# cemperation is grundwing the
# intermination of the will name: he has feeling unlets them, concerning the belief in the old individualit of
# berlic
# dream of him, but many do any seeming,
# dual on, there is europe with a man lies--what so makes a subtle man weicater, german witoon, t
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form. to one's lexius for if i hodingly partially
# indipritures, wishes led to a loblring-ypungetted ear. in rack to be looks another is teaches "uws of the severity were than which yous
# takes morality dud
# with just panded, our the claso," war-whenefue case exist a
# mysely and assertions in
# lityer thusion unvoly-dinger, the soul! "oble and complarefaned
# hitherto four seems to
# assume is  as really basi
# 에포크 57
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2419
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for example, and in the same time of the problem of the same tastes of the conscience of the spirit and aristocratic conscience of the same will to realord to the same time and the profoundly of the respect of the spirit of the same time and soleness and the problem of the same time of the sense of the same times of the same will to say to the same thing and the sensus and the strengtom of the same
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for instance, the stupidity of the world, which makes himself to seldom here the general philosophers from a personal proses to say, the most
# noise interpretation, and conditions to the religious regard
# to such a man who profound the man are to really asceticism and the conceptions of the people of the conscience of humanity in men, promped to the greater interpretation of the defer of the are not b
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for really
# greek, is always within us and healthy remarns unromened relines the man easing itself, is finally uagigus", just, where heases, we had understane, perhaps oly a one mult or many things even modes to dispuriate explained
# and all imagined,
# legs auxhist, its world. as sloddinine--magician and equiant regard, but blok bols and envelogivaties and radald him, must do themselves. fear and pain"
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fominging, the words of yus should
# decideners, we hive the superpretor mean storey hopiness in
# remain of deely men a worps. woman, just he suffers nituraking eye would niguered biclemed obat the ensade applrantage as thrirdgs too afteroun
# to growt our later fear dargmency, for excepose that praise badly it assouth. the germans which see 'natured within to
# pernacimenting
# bist colons of the o coverefu
# 에포크 58
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2423
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former as the state of the strength to the state of the state of the strength of the state of the strength of the strength to the strength of the state of the philosophers of the strength and destruction of the strength of the spirit of the state of the world of the stool of the spirit of the personal personages of the presence of the state of the state of the state of the spirit of the spirit of th
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly great shall in the earth and say, as it is man in the sentimation and bland
# it seem to the man the errorine of the presence of the order of the faith of a point of the conception of the most something of such a promps of the sake form
# of the
# world which is not surriousness and delicate themselves of the sense of
# europe, and as a matters--is well the there
# for great self so thin that it as a
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former, as if
# it is a progless in the trausaris ugod and the
# fear, all systeitesqueltor with a mas lenget.
# the germans before the most distingured, are
# interpretation more
# beternt, things, that the sasting neeling, it is
# virtue. there nows formerly bad before it were immense off for what
# in their great sining to
# come perhaps better among it: there are
# herather
# in a ided by the case when they are pos
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore--as a thot is a colours.
#
#
# o xox, to be evidence, to
# my what still accustohima-
# clost, upon which the befakedqual nonly, to by a "uncession of "quidation of this
# dastor
# withedings to
# term that the wowoder ol!lia. where asougher fear to feel question
# of
# ming it besidiol turns, by a die
# new truth at this
# circiption and own himselfed: at something
# xiwly, and
# owils would child and averitus
# premised
# 에포크 59
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2423
# --- 시드 텍스트: the slowly ascending ranks and classes, in which,
# through fo
# --- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for instance, the more the more something of the sense of the same things and artists of the conception of the condition:
# that is the belief in the counter of the sense of the same things of the sense of the consequences, and the struggle and desire to the most soul of the opposite of the same things of the same things of the condition. in the condition-cons of the most consequently of the consequen
# --- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for instruct and desire to his value conception in his artists and distrustgless and into the opposite of the condition.
#
# 111. onexe of the sinise, as the command" in the condition.
#
# 211. a more personal is the man has distinguish such a precisely in the origin of the same state of conscience of the reared of the desire of the instincts of nature in the german reference of the origin of the especial
# --- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for "tain. the man, will to be our by god and eyes, which is inferion for deepent and lamey fally taste.
#
# he happens masters, are entertaon and
# numble, she hears to boiked existed even and follows
# lofty express"s! bolopary would look at himself exultine on nature,--maketoded in order that it is ago distingly every gregual, will required, and
# siked in their duty of which we halt to the esercious to s
# --- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for which in those
# problem--the idoe is replised "festiving of numbladed--which?
#     schooors
# a play.=--they courses when last being ethica of which
# its required sided and sameow, his
# hason
# being is to castfolbemacl, what divinate will, into !obshe in an acloftinh, herlty, one wsely will to
# the effestings of the man.--but i realt, but class--mufforicals irigar, indi-lvaringe is the weak; it be wast
